# %%
from PIL import Image

def upscale_image(input_path, output_path):
    # Open the image
    original_image = Image.open(input_path)

    # Upscale using bicubic interpolation
    upscaled_image = original_image.resize((256, 256), Image.BICUBIC)

    # Save the upscaled image
    upscaled_image.save(output_path)

# Example usage:
# input_image_path = "generation-5/pokemon/main-sprites/black-white/1.png"
# output_image_path = "C:/Users/David/Desktop/U-TAD/5to AÑO/1er cuatrimestre/Vision por computador/Practicas/Practica 3, Tema 4/upscaled_image.png"

upscale_image(input_image_path, output_image_path)

# %%
import json
# Specify the path to your JSON file
json_file_path = 'tipos.json'

# Open the JSON file and load its content into a dictionary
with open(json_file_path, 'r') as json_file:
    data = json.load(json_file)

# Now, 'data' is a dictionary containing the content of your JSON file
print(data)
# Out:
# {'Grass': ['generation-5/pokemon/main-sprites/black-white/1.png', 'generation-5/pokemon/main-sprites/black-white/2.png', 'generation-5/pokemon/main-sprites/black-white/3.png', 'generation-5/pokemon/main-sprites/black-white/43.png', 'generation-5/pokemon/main-sprites/black-white/44.png', 'generation-5/pokemon/main-sprites/black-white/45.png', 'generation-5/pokemon/main-sprites/black-white/46.png', 'generation-5/pokemon/main-sprites/black-white/47.png', 'generation-5/pokemon/main-sprites/black-white/69.png', 'generation-5/pokemon/main-sprites/black-white/70.png', 'generation-5/pokemon/main-sprites/black-white/71.png', 'generation-5/pokemon/main-sprites/black-white/102.png', 'generation-5/pokemon/main-sprites/black-white/103.png', 'generation-5/pokemon/main-sprites/black-white/114.png', 'generation-5/pokemon/main-sprites/black-white/152.png', 'generation-5/pokemon/main-sprites/black-white/153.png', 'generation-5/pokemon/main-sprites/black-white/154.png', 'generation-5/pokemon/main-sprit
# ...

# %%
for tipo,rutas in data.items():
    for ruta in rutas:
        upscale_image(ruta, ruta)
